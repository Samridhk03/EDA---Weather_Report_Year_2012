# %% [markdown]
# <a href="https://colab.research.google.com/github/Samridhk03/EDA---Weather_Report_Year_2012/blob/main/EDA_Weather_Report_Year_2012.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exploratory Data Analysis for the Weather Report of the Year 2012

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/weather_2012.csv', parse_dates = True, index_col= 'Date/Time')
df
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
# ...                       ...                 ...          ...
# 2012-12-31 19:00:00       0.1                -2.7           81
# 2012-12-31 20:00:00       0.2                -2.4           83
# 2012-12-31 21:00:00      -0.5                -1.5           93
# 2012-12-31 22:00:00      -0.2                -1.8           89
# 2012-12-31 23:00:00       0.0                -2.1           86
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8784 entries, 2012-01-01 00:00:00 to 2012-12-31 23:00:00
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Temp (C)            8784 non-null   float64
#  1   Dew Point Temp (C)  8784 non-null   float64
#  2   Rel Hum (%)         8784 non-null   int64
#  3   Wind Spd (km/h)     8784 non-null   int64
#  4   Visibility (km)     8784 non-null   float64
#  5   Stn Press (kPa)     8784 non-null   float64
#  6   Weather             8784 non-null   object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 549.0+ KB

# %%
df.shape
# Out:
# (8784, 7)

# %% [markdown]
# 1. How did the temperature vary amongst the months during the year?

# %%
#Grouping the data on the basis of month

monthly_data = df.groupby(df.index.month).mean()
monthly_data
# Out:
# <ipython-input-20-11963e7937c3>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   monthly_data = df.groupby(df.index.month).mean()
#             Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# Date/Time
# 1          -7.371505          -12.294758    68.383065        18.108871
# 2          -4.225000           -9.221695    68.956897        14.837644
# 3           3.121237           -3.488575    64.862903        14.514785
# 4           7.009306           -1.934583    56.150000        17.369444
# 5          16.237769            8.080780    61.760753        12.846774
# 6          20.134028           11.738056    60.643056        14.681944
# 7          22.790054           14.595430    62.017473        11.887097
# 8          22.279301           15.644758    67.943548        13.931452
# ...

# %%
x = monthly_data.index
y = monthly_data['Temp (C)']

# %%
plt.plot(x,y)
plt.title('Temperature Trend of Year 2012')
plt.xlabel('Months')
plt.xticks(x)
plt.ylabel('Temp in "C"')
plt.show()
# Out:
# Text(0, 0.5, 'Temp in "C"')

# %%
# Converting month numbers to actual month name in the x axis
import calendar
months = calendar.month_name[1:]
print(months)
# Out:
# ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
#Writing the code again to plot the chart

plt.plot(months,y)
plt.title('Temperature Trend of Year 2012')
plt.xlabel('Months')
plt.xticks(months, rotation = 50)
plt.ylabel('Temp in "C"')
plt.figure(figsize = (10,8))
plt.show()

# %% [markdown]
# 2. Find the variation in mean visibility, aggregated by days of the week

# %%
weekly_data = df.groupby(df.index.dayofweek).mean()
weekly_data
# Out:
# <ipython-input-64-6d87349084e7>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   weekly_data = df.groupby(df.index.dayofweek).mean()
#            Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# Date/Time
# 0          8.853931            2.354874    66.372642        15.700472
# 1          8.889583            3.159135    69.260417        14.628205
# 2          8.806891            3.029728    69.239583        13.608974
# 3          9.456731            3.337179    67.767628        15.044872
# 4          9.353766            3.257772    68.695513        15.500801
# 5          8.388622            1.535657    65.132212        15.185096
# 6          7.854560            1.241824    65.609277        14.935535
#
#            Visibility (km)  Stn Press (kPa)
# Date/Time
# ...

# %%
plt.bar(weekly_data.index,weekly_data['Visibility (km)'])
plt.title('Visibility by the Week')
plt.xlabel('Days')
plt.xticks(weekly_data.index, calendar.day_abbr, rotation = 10)
plt.ylabel('Visibility (KM)')
# Out:
# Text(0, 0.5, 'Visibility (KM)')

# %% [markdown]
# 3. Viewing the average Wind speed amongst the Months

# %%
plt.plot(months, monthly_data['Wind Spd (km/h)'])
plt.title('Wind Speed during the Year 2012')
plt.xlabel('Months')
plt.ylabel('Wind Speed Km/Hr')
plt.xticks(months, rotation = 40)
plt.show()

# %% [markdown]
# 4. Comparison between the mean of Dew and Humidity amongst the months

# %%
fig, weather = plt.subplots()
weather.plot(months,monthly_data['Dew Point Temp (C)'], 'b.-')
weather.plot(months,monthly_data['Rel Hum (%)'], 'g--')
plt.xticks(months, rotation = 45)
fig.show()

# %% [markdown]
# 5. Comparing the Overall Weather

# %%
fig, overall_weather= plt.subplots()
overall_weather.plot(months, y, c = 'r')
overall_weather.plot(months, monthly_data['Wind Spd (km/h)'], 'b--')
overall_weather.plot(months,monthly_data['Dew Point Temp (C)'], 'g.-')
plt.xticks(months, rotation = 45)
fig.show()
